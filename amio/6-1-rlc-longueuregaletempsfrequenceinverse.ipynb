# %% [markdown]
# Jeudi 4 janvier 2018 14h08

# %% [markdown]
# https://euler.ac-versailles.fr/webMathematica/tmd/ecoutez.PDF

# %%
r=sqrt(4.0/n(pi));r
l=1/2.0;f=1/l;r
# Out:
# 1.12837916709551

# %%
c=9.0/8.0

# %% [markdown]
# $r$ est le rapport exact pour avoir un carré de même surface qu'un cercle, carré de $c^2$ ($2^2=4$) et cercle $\pi r^2$, avec $r=\sqrt \frac {4}{\pi}$

# %%
f=x;a=plot(x);b=plot(-x)
po = polygon(((-1,-1),(-1,1),
              (1,1),(1,-1)),color="blue",
             edgecolor="red",thickness=1,
             alpha=0.3)
cr = circle((0,0),r,color="red",
            zorder=-5,thickness=1)
co = circle((0,0),r/1.22,color="orange",
            zorder=-5,thickness=1)
show(cr+a+b+po,
     xmin=-1.2,xmax=1.2,ymin=-1.2,ymax=1.2,
     gridlines="minor",
     gridlinesstyle=dict(color="green",
                         linestyle="-"),
     axes=False,frame=True,figsize=5,fontsize=8)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
f=x;a=plot(x);b=plot(-x)
po = polygon(((-1,-1),(-1,1),
              (1,1),(1,-1)),color="blue",
             edgecolor="red",thickness=1,
             alpha=0.3)
cr = circle((0,0),r,color="red",
            zorder=-5,thickness=1)
c4 = circle((0,0),r/1.33,color="blue",
            zorder=-5,thickness=1)
c8 = circle((0,0),r/8,color="brown",
            zorder=-5,thickness=1)
show(cr+a+b+po+c8+c4,
     xmin=-1.2,xmax=1.2,ymin=-1.2,ymax=1.2,
     gridlines="minor",
     gridlinesstyle=dict(color="green",
                         linestyle="-"),
     axes=False,frame=True,figsize=10,fontsize=8)
# Out:
# Graphics object consisting of 6 graphics primitives

# %%
1/(1/5.0)
# Out:
# 5.00000000000000

# %%
1/0.0023540
# Out:
# 424.808836023789

# %%
1/0.002812
# Out:
# 355.618776671408

# %%
1/0.003427
# Out:
# 291.800408520572

# %%
1/0.001937
# Out:
# 516.262261228704
