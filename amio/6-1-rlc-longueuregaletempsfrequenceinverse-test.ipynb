# %% [markdown]
# Jeudi 4 janvier 2018 14h08---samedi 6/1/14h12

# %% [markdown]
# https://euler.ac-versailles.fr/webMathematica/tmd/ecoutez.PDF

# %%
r=sqrt(4.0/n(pi));r
l=1/2.0;f=1/l;r
# Out:
# 1.12837916709551

# %% [markdown]
# $r$ est le rapport exact pour avoir un carré de même surface qu'un cercle, carré de $c^2$ ($2^2=4$) et cercle $\pi r^2$, avec $r=\sqrt \frac {4}{\pi}$

# %%
f=x;a=plot(x);b=plot(-x)
po = polygon(((-1,-1),(-1,1),
              (1,1),(1,-1)),color="blue",
             edgecolor="red",thickness=1,
             alpha=0.3)
cr = circle((0,0),r,color="red",
            zorder=-5,thickness=1)
co = circle((0,0),r/1.22,color="orange",
            zorder=-5,thickness=1)
show(cr+a+b+po,
     xmin=-1.2,xmax=1.2,ymin=-1.2,ymax=1.2,
     gridlines="minor",
     gridlinesstyle=dict(color="green",
                         linestyle="-"),
     axes=False,frame=True,figsize=5,fontsize=8)
# Out:
# Graphics object consisting of 4 graphics primitives

# %% [markdown]
# Chine antique entre -5000 et -10000
#
# Découverte du son primordial : Ton FA =1 (0) amiot-p93
# "Je fupprime ici diverfes fables que racontent les Chinois favoir, que Lyng-lun prit l'un de, ces tuyaux, le coupa entre deux noeuds en ôta la moelle, fouffla
# dans le tuyau, & qu'il en fortit un fon qui n'etoit, ni plus haut, ni plus bas que le ton qu'il prenoit lui-même lorfqu'il parloit fans être affecté d aucune paffion ; effet bien plus que merveilleux, puifque
# dans un tuyau ainfi ouvert & auffi court qu'on le fuppofe (étantcoupé entre deux noeuds ) le, fouffle doit parler de part en part fans rendre aucun fon. Quoi qu'il en foit, non loin de-là, la fource du fleuve Hoang-ho Sortant de terre avec bouillonnement, rend un fon, & ce fon etoit précisément fur le ton du tuyau ouvert par fes deux bouts. Voilà le premier fon
# le fon fondamental des Lu, bien, établi. Mais voici tous les douze Lu. Le foung-hoang ( oifeau comme notre phénix ) , accompagné de fa femelle, vient tout-à-coup fe percher fur un arbre voifin, le mâle donne fix fons différens, &c... la femelle fix autres : voilà bien
# les fix lu yang !

# %%
round((pi)*r^2/(2*2))
# Out:
# 1
