# %% [markdown]
# COSMOS Cluster 9 - 2014
# <br>
# <a http://guitar.ucsd.edu>guitar.ucsd.edu</a>

# %% [markdown]
# # Waves

# %% [markdown]
# Before we start we perform some initialization to load some ploting and mathematical libraries:

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Sine Waves

# %% [markdown]
# A sinusoidal wave or sine wave is characterized by three parameters:
# <ul>
# <li>Frequency (f, in Hertz)
# <li>Phase ($\phi$ in radians)
# <li>Amplitude (wathever the wave unit)
# </ul>
#
# <p>Mathematically:
#
# <p>$$x(t) = A \sin(2 \, \pi \, f \, t + \phi)$$
#
# <p>The sine wave is <em>periodic</em> and its <em>period</em> (in seconds) is:
#
# <p>$$T = \frac{1}{f}$$
#
# <p>Here is an example:

# %%
f = 1
A = 1
phi = 0
t = np.linspace(0, 5, 500)              # the prefix np. invokes functions in the numpi library
plt.plot(t, A*np.sin(2*np.pi*f*t+phi))  # the prefix plt. invokes functions in the matplotlib library
plt.title('Sine Wave, f = %d Hz' % f);
plt.xlabel('t (s)');
plt.ylabel('x(t)');
plt.grid(1)

# %% [markdown]
# <p>Now it is your turn:
#
# <p>Modify f, A, $\phi$ to obtain:
#
# <ul>
# <li>A wave with amplitude equal to 2 and period equal to 2s
# <li>A wave with amplitude 1 and period 1s that equals 1 when t = 0s
# <li>A wave with amplitude 1 and period 1s that equals 1 when t = 0.5s
# </ul>

# %% [markdown]
# <p>Here are some intriguing questions:
#
# <ul>
# <li>Can the amplitude be zero? Can the amplitude be negative?
# <li>Can the frequency be negative?
# <li>What happens if the frequency and phase are both zero?
# <li>What happens if the frequency is zero but the phase is 90$^\circ$ ($\pi/2$)?
# <li>Can the phase be negative?
# </ul>
#
# <p>Try plotting!

# %% [markdown]
# ### Understanding Phase

# %% [markdown]
# The effect of phase can be understood in light of the trigonometric identity:
#
# <p>$$\sin(a+b) = \sin a \cos b + \sin b \cos a$$
#
# <p>If we let $a = 2 \, \pi \, f \, t$ and $b = \phi$ then:
#
# <p>$$\sin(2 \, \pi \, f \, t + \phi) = \cos \phi \sin(2 \, \pi \, f \, t) + \sin \phi \cos(2 \, \pi \, f \, t)$$
#
# <p> Your turn:
#
# <ul>
# <li>Try $\phi = 0$, $\phi = 90^\circ$ ($\pi/2$), $\phi = 180^\circ$ ($\pi$).
# <li>Try $\phi = 45^\circ$ ($\pi/4$)?
# </ul>

# %% [markdown]
# ## Summing Sine Waves with Same Frequencies

# %% [markdown]
# When sine waves <b>with same frequency</b> are added together the result is still periodic with same frequency.
#
# <p>If the <b>phase is also the same</b> then the it's easy:
#
# <p>$$A \sin(2 \, \pi \, f \, t+ \phi) + B \sin(2 \, \pi \, f \, t+ \phi) = (A + B) \sin(2 \, \pi \, f \, t + \phi)$$

# %%
f = 1
A = 1
B = 1
phi = 0
t = np.linspace(0, 5, 500)
plt.plot(t, A*np.sin(2*np.pi*f*t+phi) + B*np.sin(2*np.pi*f*t+phi))
plt.title('Sine Wave, f = %d Hz' % f);
plt.xlabel('t (s)');
plt.ylabel('x(t)');
plt.grid(1)

# %% [markdown]
# <p> Your turn:
#
# <ul>
# <li>Try different amplitudes ($A$, $B$) and phase ($\phi$)
# </ul>

# %% [markdown]
# <p>If the <b>phase is different</b> but the <b>amplitude is the same</b>:
#
# <p>$$\begin{align*}
# \sin(2 \, \pi \, f \, t) + \sin(2 \, \pi \, f \, t + \phi) &= \sin(2 \, \pi \, f \, t) + \cos(\phi) \sin(2 \, \pi \, f \, t) + \sin(\phi) \cos(2 \, \pi \, f \, t) \\
# &= (1 + \cos \phi) \sin(2 \, \pi \, f \, t) + \sin \phi \cos(2 \, \pi \, f \, t)
# \end{align*}$$

# %%
f = 1
phi = np.pi/2
t = np.linspace(0, 5, 500)
plt.plot(t, np.sin(2*np.pi*f*t) + np.sin(2*np.pi*f*t+phi))
plt.title('Sine Wave, f = %d Hz' % f);
plt.xlabel('t (s)');
plt.ylabel('x(t)');
plt.grid(1)

# %% [markdown]
# <p> Your turn:
#
# <ul>
# <li>Try $\phi = 0$, $\phi = 90^\circ$ ($\pi/2$), $\phi = 45^\circ$ ($\pi/4$).
# <li>Try $\phi = 180^\circ$ ($\pi$).
# <li>What difference it makes if the amplitude is not equal to $1$?
# <li>What if the phase is different but the amplitude is not? Try plotting!
# </ul>

# %% [markdown]
# ## Summing Sine Waves with Different Frequencies

# %% [markdown]
# When sine waves with different frequencies are added together things get a lot more complicated...
#
# <p><b>Sometimes</b> the result <em>is</em> periodic:

# %%
f1 = 1
f2 = 2
t = np.linspace(0, 5, 500)
plt.plot(t, np.sin(2*np.pi*f1*t) + np.sin(2*np.pi*f2*t))
plt.title('Sine Wave, f = %d Hz' % f);
plt.xlabel('t (s)');
plt.ylabel('x(t)');
plt.grid(1)

# %% [markdown]
# <p> Your turn:
#
# <ul>
# <li>What is the period of the above wave?
# <li>What is the ratio between the periods of the components?
# </ul>

# %% [markdown]
# Sometimes the result <em>is not</em> periodic (even though it may <em>look</em> so!):

# %%
f1 = 1
f2 = np.pi
t = np.linspace(0, 10, 500)
plt.plot(t, np.sin(2*np.pi*f1*t) + np.sin(2*np.pi*f2*t))
plt.title('Sine Wave, f = %d Hz' % f);
plt.xlabel('t (s)');
plt.ylabel('x(t)');
plt.grid(1)

# %% [markdown]
# <p> Your turn:
#
# <ul>
# <li>Can you explain why the above sum of sine waves is not periodic?
# <li>What is the ratio between the periods of the components?
# </ul>

# %% [markdown]
# Sometimes the period is not what you may think it is:

# %%
f1 = 2
f2 = 3
t = np.linspace(0, 6, 500)
plt.plot(t, np.sin(2*np.pi*f1*t) + np.sin(2*np.pi*f2*t))
plt.title('Sine Wave, f = %d Hz' % f);
plt.xlabel('t (s)');
plt.ylabel('x(t)');
plt.grid(1)

# %% [markdown]
# <p> Your turn:
#
# <ul>
# <li>What is the period of the above wave?
# <li>What is the ratio between the periods of the components?
# </ul>

# %% [markdown]
# When the frequencies are very close to each other:

# %%
f1 = 1
f2 = 1.1
t = np.linspace(0, 6, 500)
plt.plot(t, np.sin(2*np.pi*f1*t) + np.sin(2*np.pi*f2*t))
plt.title('Sine Wave, f = %d Hz' % f);
plt.xlabel('t (s)');
plt.ylabel('x(t)');
plt.grid(1)

# %% [markdown]
# you may want to look (or hear) from far away:

# %%
f1 = 1
f2 = 1.1
t = np.linspace(0, 20, 500)
plt.plot(t, np.sin(2*np.pi*f1*t) + np.sin(2*np.pi*f2*t))
plt.title('Sine Wave, f = %d Hz' % f);
plt.xlabel('t (s)');
plt.ylabel('x(t)');
plt.grid(1)

# %% [markdown]
# <p> Your turn:
#
# <ul>
# <li>What is the period of the above wave?
# <li>What is the ratio between the periods of the components?
# </ul>
